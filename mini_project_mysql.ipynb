# %%
from tabulate import tabulate

# %%
import mysql.connector

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
mydb=mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "root12345",
    port = "3306"
)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:root12345@localhost/project')

# %%
df = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\guvi\\mini project\\c_data.csv")   # or pd.read_excel()
print(df.head())
# Out:
#                     name online_order book_table  rate  votes      location  \
# 0                  jalsa          yes        yes   4.1    775  banashankari
# 1         spice_elephant          yes         no   4.1    787  banashankari
# 2        san_churro_cafe          yes         no   3.8    918  banashankari
# 3  addhuri_udupi_bhojana           no         no   3.7     88  banashankari
# 4          grand_village           no         no   3.8    166  basavanagudi
#
#            rest_type                                         dish_liked  \
# 0       casualdining  pasta,_lunch_buffet,_masala_papad,_paneer_laja...
# 1       casualdining  momos,_lunch_buffet,_chocolate_nirvana,_thai_g...
# 2  cafe,casualdining  churros,_cannelloni,_minestrone_soup,_hot_choc...
# 3         quickbites                                        masala_dosa
# 4       casualdining                                panipuri,_gol_gappe
#
#                          cuisines  approx_cost(for two people)  \
# 0  north_indian,_mughlai,_chinese                        800.0
# 1     chinese,_north_indian,_thai                        800.0
# 2          cafe,_mexican,_italian                        800.0
# 3      south_indian,_north_indian                        300.0
# 4        north_indian,_rajasthani                        600.0
#
#   listed_in(type) listed_in(city)      mobile
# 0          buffet    banashankari  9743772233
# 1          buffet    banashankari  8041714161
# 2          buffet    banashankari  9663487993
# 3          buffet    banashankari  9620009302
# 4          buffet    banashankari  9901210005

# %%
df.to_sql('target_table_name', con=engine, index=False, if_exists='append')
# Out:
# 23152

# %%
mycursor=mydb.cursor()

# %%
mycursor.execute("create database project")

# %%
mycursor.execute("use project")

# %%
mycursor = mydb.cursor()
mycursor.execute("SHOW TABLES")
for table in mycursor:
    print(table)
# Out:
# ('target_table_name',)
# ('uber_eats_res_data',)

# %%
mycursor.execute("rename table target_table_name to uber_eats_res_data")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'uber_eats_res_data' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 mycursor.execute("rename table target_table_name to uber_eats_res_data")
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:356, in CMySQLCursor.execute(self, operation, params, map_results)
#     348 self._executed = (
#     349     self._stmt_partition["single_stmts"].popleft()
#     350     if map_results
#     351     else self._stmt_partition["mappable_stmt"]
#     352 )
#     354 try:
#     355     self._handle_result(
# --> 356         self._connection.cmd_query(
#     357             self._stmt_partition["mappable_stmt"],
#     358             raw=self._raw,
#     359             buffered=self._buffered,
#     360             raw_as_string=self._raw_as_string,
#     361         )
#     362     )
#     363 except MySQLInterfaceError as err:
#     364     if hasattr(err, "errno"):
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:781, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     779 except MySQLInterfaceError as err:
#     780     if hasattr(err, "errno"):
# --> 781         raise get_mysql_exception(
#     782             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     783         ) from err
#     784     raise InterfaceError(str(err)) from err
#     785 except AttributeError as err:
#
# ProgrammingError: 1050 (42S01): Table 'uber_eats_res_data' already exists

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'dish_liked', 'cuisines', 'approx_cost(for two people)',
#        'listed_in(type)', 'listed_in(city)', 'mobile'],
#       dtype='object')

# %%
# Qus : 1. # Which Bangalore locations have the highest average restaurant ratings?
# Business Value: Identifies premium-performing areas suitable for brand positioning and new partner onboarding.

# %%
mycursor.execute("""select location,avg(rate) from uber_eats_res_data
where rate is not null
group by location
order by avg(rate) desc""")
out=mycursor.fetchall()
print(tabulate(out,headers=[i[0]for i in mycursor.description],tablefmt='psql'))
# Out:
# +-------------------------------+-------------+
# | location                      |   avg(rate) |
# |-------------------------------+-------------|
# | lavelle_road                  |     4.19182 |
# | koramangala_5th_block         |     4.15275 |
# | sankey_road                   |     4.10588 |
# | koramangala_3rd_block         |     4.10124 |
# | cunningham_road               |     4.1003  |
# | st._marks_road                |     4.09901 |
# | koramangala_2nd_block         |     4.07333 |
# | sadashiv_nagar                |     4.05526 |
# | residency_road                |     4.05057 |
# | church_street                 |     4.04515 |
# | koramangala_4th_block         |     4.04488 |
# | seshadripuram                 |     4.03188 |
# | richmond_road                 |     4.02906 |
# | ulsoor                        |     4.02101 |
# | koramangala                   |     4.01176 |
# | koramangala_7th_block         |     3.99115 |
# | race_course_road              |     3.98667 |
# | hosur_road                    |     3.98333 |
# | malleshwaram                  |     3.96612 |
# | koramangala_8th_block         |     3.96452 |
# | indiranagar                   |     3.96245 |
# | mg_road                       |     3.95328 |
# | hennur                        |     3.95294 |
# | vasanth_nagar                 |     3.95    |
# | koramangala_6th_block         |     3.94721 |
# | hbr_layout                    |     3.94286 |
# | brigade_road                  |     3.94162 |
# | jayanagar                     |     3.93693 |
# | kalyan_nagar                  |     3.9364  |
# | city_market                   |     3.92857 |
# | shivajinagar                  |     3.90145 |
# | langford_town                 |     3.9     |
# | magadi_road                   |     3.9     |
# | yelahanka                     |     3.9     |
# | sanjay_nagar                  |     3.9     |
# | sarjapur_road                 |     3.89251 |
# | majestic                      |     3.88889 |
# | infantry_road                 |     3.8883  |
# | kammanahalli                  |     3.88115 |
# | koramangala_1st_block         |     3.87489 |
# | rajajinagar                   |     3.86115 |
# | new_bel_road                  |     3.8571  |
# | jp_nagar                      |     3.85443 |
# | rajarajeshwari_nagar          |     3.85    |
# | hsr                           |     3.84057 |
# | vijay_nagar                   |     3.84    |
# | basavanagudi                  |     3.83671 |
# | basaveshwara_nagar            |     3.82394 |
# | thippasandra                  |     3.82093 |
# | whitefield                    |     3.81808 |
# | wilson_garden                 |     3.81707 |
# | banashankari                  |     3.81344 |
# | old_airport_road              |     3.81188 |
# | frazer_town                   |     3.79659 |
# | yeshwantpur                   |     3.775   |
# | sahakara_nagar                |     3.775   |
# | btm                           |     3.7564  |
# | mysore_road                   |     3.75    |
# | ejipura                       |     3.74828 |
# | marathahalli                  |     3.73368 |
# | brookefield                   |     3.69935 |
# | electronic_city               |     3.6954  |
# | commercial_street             |     3.69291 |
# | domlur                        |     3.68641 |
# | jeevan_bhima_nagar            |     3.68391 |
# | bannerghatta_road             |     3.68226 |
# | bellandur                     |     3.68095 |
# | nagawara                      |     3.66774 |
# | shanti_nagar                  |     3.65723 |
# | varthur_main_road,_whitefield |     3.65556 |
# | itpl_main_road,_whitefield    |     3.64762 |
# | banaswadi                     |     3.64103 |
# | jalahalli                     |     3.63333 |
# | cv_raman_nagar                |     3.62857 |
# | kumaraswamy_layout            |     3.62321 |
# | rt_nagar                      |     3.61364 |
# | kr_puram                      |     3.6     |
# | central_bangalore             |     3.6     |
# | north_bangalore               |     3.6     |
# | uttarahalli                   |     3.575   |
# | kaggadasapura                 |     3.56458 |
# | east_bangalore                |     3.5125  |
# | rammurthy_nagar               |     3.43333 |
# | kanakapura_road               |     3.4     |
# | south_bangalore               |     3.38421 |
# | west_bangalore                |     3.3     |
# | old_madras_road               |     3.1375  |
# | bommanahalli                  |     3.13571 |
# +-------------------------------+-------------+

# %%
# Ans:
# Based on my analysis, 
# Lavelle Road (4.19), 
# Koramangala 5th Block (4.15), 
# and Sankey Road (4.10) have the highest average restaurant ratings in Bangalore.”
# these areas very suitable for brand positioning and new partner onboarding.

# these areas are lowest avarage rateing having.
#not suitable for brand positioning and new partner onboarding

south_bangalore      (3.3)
west_bangalore       (3.3)
old_madras_road      (3.1)
bommanahalli         (3.1)

# %%
# Which locations are over-saturated with restaurants?
 # Business Value: Helps avoid overcrowded markets and guides smarter expansion decisions.

# %%
mycursor.execute("""select location,count(*)total from uber_eats_res_data
group by location
order by count(name) desc limit 5""")
out=mycursor.fetchall()
print(tabulate(out,headers=[i[0]for i in mycursor.description],tablefmt='psql'))
# Out:
# +-----------------------+---------+
# | location              |   total |
# |-----------------------+---------|
# | koramangala_5th_block |    1782 |
# | btm                   |    1454 |
# | indiranagar           |    1345 |
# | hsr                   |    1161 |
# | jayanagar             |    1037 |
# +-----------------------+---------+

# %%
# based on my analysis,

#koramangala 5th bolck , this area has a 1782no of resturant
# btm has a 1454no of resturant
# indranagar has a 1345 no of resturants
#hsr has a 1161 no of resturants
#jayanagar has a 1037 no of resturants

# %%
# QUS:3 Does online ordering improve restaurant ratings?
# Business Value: Evaluates the ROI of Uber Eats’ online ordering feature for partners.

# %%
mycursor.execute("""select online_order,avg(rate), count(*) from uber_eats_res_data
group by online_order """)
out=mycursor.fetchall()
print(tabulate(out,headers=[i[0]for i in mycursor.description],tablefmt='psql'))
# Out:
# +----------------+-------------+------------+
# | online_order   |   avg(rate) |   count(*) |
# |----------------+-------------+------------|
# | yes            |     3.89349 |      16328 |
# | no             |     3.93104 |       6824 |
# +----------------+-------------+------------+

# %%
#online order does not improving restaurant rating.
#it shows the online orders alone does not significantly improve restaurant rating
#Therefore, Uber Eats may need to focus on improving delivery experience, order accuracy, and service quality to increase partner ROI.”

# %%
#QUS 4: # Does table booking correlate with higher customer ratings?
# Business Value: Measures the effectiveness of table booking as a premium feature.

# %%
mycursor.execute("""select book_table, avg(rate),count(*)as total from uber_eats_res_data
group by book_table""")
out=mycursor.fetchall()
print(tabulate(out,headers=[i[0]for i in mycursor.description],tablefmt='psql'))
# Out:
# +--------------+-------------+---------+
# | book_table   |   avg(rate) |   total |
# |--------------+-------------+---------|
# | yes          |     4.15802 |    6098 |
# | no           |     3.81393 |   17054 |
# +--------------+-------------+---------+

# %%
# COMBINE OF ONLINE ORDER AND TABLE BOOKING OPTIONS SIGNIFICANTLY IMPROVING THE RATING OF THE RESTAURENT
# “This indicates a strong positive correlation between table booking and ratings.
# Customers likely prefer convenience and reduced waiting time.”

# %%
#QUS 5: What price range delivers the best customer satisfaction?
# Business Value: Helps define the optimal pricing segment for partner success.

# %%
mycursor.execute("""select `approx_cost(for two people)`,avg(rate),count(
*)name from uber_eats_res_data
group by `approx_cost(for two people)`
order by avg(rate) desc""")
out=mycursor.fetchall()
print(tabulate(out,headers=[i[0]for i in mycursor.description],tablefmt='psql'))
# Out:
# +-------------------------------+-------------+--------+
# |   approx_cost(for two people) |   avg(rate) |   name |
# |-------------------------------+-------------+--------|
# |                          2700 |     4.5     |      2 |
# |                           120 |     4.4     |      2 |
# |                          3200 |     4.4     |      2 |
# |                          1600 |     4.3318  |    239 |
# |                          3500 |     4.328   |     25 |
# |                          1250 |     4.3     |      9 |
# |                          1650 |     4.3     |      6 |
# |                          5000 |     4.3     |      1 |
# |                          6000 |     4.3     |      2 |
# |                          4500 |     4.3     |      2 |
# |                          3400 |     4.3     |     13 |
# |                          2800 |     4.2871  |     31 |
# |                          1700 |     4.28233 |    232 |
# |                          4000 |     4.25833 |     24 |
# |                          1800 |     4.23492 |    189 |
# |                          1400 |     4.22867 |    443 |
# |                           180 |     4.22353 |     17 |
# |                          2500 |     4.2007  |    142 |
# |                          3000 |     4.2     |    159 |
# |                          2300 |     4.2     |      1 |
# |                          1500 |     4.19625 |    853 |
# |                          1900 |     4.19123 |     57 |
# |                          2400 |     4.19091 |     22 |
# |                          1300 |     4.17591 |    494 |
# |                          2100 |     4.14444 |     63 |
# |                          2000 |     4.1432  |    294 |
# |                          2600 |     4.1     |      4 |
# |                          4100 |     4.1     |      4 |
# |                          1200 |     4.0941  |    899 |
# |                          2200 |     4.09231 |     39 |
# |                          1100 |     4.08522 |    460 |
# |                           900 |     4.0588  |    517 |
# |                          1450 |     4.02    |      5 |
# |                          3700 |     4       |      1 |
# |                          1000 |     3.99799 |   1241 |
# |                           230 |     3.99    |     10 |
# |                           100 |     3.97265 |    117 |
# |                           150 |     3.94672 |    366 |
# |                           800 |     3.93361 |   1657 |
# |                           850 |     3.8918  |    122 |
# |                           750 |     3.8894  |    651 |
# |                           950 |     3.87872 |     47 |
# |                           700 |     3.87274 |   1159 |
# |                           200 |     3.83426 |    861 |
# |                           300 |     3.82349 |   1686 |
# |                           400 |     3.81664 |   2464 |
# |                           600 |     3.81623 |   2169 |
# |                           550 |     3.81139 |    439 |
# |                          1350 |     3.77778 |     18 |
# |                           250 |     3.75259 |    696 |
# |                           500 |     3.7452  |   2270 |
# |                            40 |     3.725   |      8 |
# |                           650 |     3.72025 |    637 |
# |                           350 |     3.7132  |    553 |
# |                           450 |     3.68347 |    720 |
# |                           330 |     2.7     |      4 |
# |                          1050 |     2.575   |      4 |
# +-------------------------------+-------------+--------+

# %%
# Mid to high price range restaurants (₹800–₹2000) deliver the best customer satisfaction, 
# as they maintain consistently high ratings with a significant number of restaurants. While very high-priced restaurants show slightly higher ratings, 
# the sample size is small, making mid-range the most reliable segment.

# %%
#QUS:6. How do low, mid, and premium-priced restaurants perform in terms of ratings?
# Business Value: Supports pricing-based market segmentation strategies.

# %%
mycursor.execute("""
select 
price_catagory,
avg(rate) as avg_rating,
count(*) as total
from(
select
     rate,
     case
        when `approx_cost(for two people)`<=500 then 'low'
        when `approx_cost(for two people)` between 501 and 1500 then 'mid'
        else 'premium'
        end as price_catagory from uber_eats_res_data
)t
group by price_catagory
order by avg_rating desc

""")

out=mycursor.fetchall()
print(tabulate(out,headers=[i[0]for i in mycursor.description],tablefmt='psql'))
# Out:
# +------------------+--------------+---------+
# | price_catagory   |   avg_rating |   total |
# |------------------+--------------+---------|
# | premium          |      4.22696 |    1554 |
# | mid              |      3.95707 |   11824 |
# | low              |      3.78977 |    9774 |
# +------------------+--------------+---------+

# %%
# Premium-priced restaurants have the highest average ratings (4.23), 
  followed by mid-range restaurants (3.96) and low-priced restaurants (3.79). 
  This indicates that customer satisfaction tends to increase with price, 
  likely due to better quality, service, and overall experience.

      “Premium restaurants provide superior experience, while mid-range offers a balance between affordability and quality.”

“However, this reflects correlation, not causation. Higher ratings may also be influenced by factors like cuisine, service quality, and location.”

# %%
# QUS: NO 7# Which cuisines are most common in Bangalore? 
# Business Value: Reveals market demand and cuisine saturation levels.

# %%
query=("select cuisines, count(*) from uber_eats_res_data group by cuisines")
df = pd.read_sql(query,mydb)

df['cuisines']=df['cuisines'].str.split(',')
df=df.explode('cuisines')

df['cuisines'] = df['cuisines'].str.strip()           
df['cuisines'] = df['cuisines'].str.replace('_','')  
df['cuisines'] = df['cuisines'].str.lower()  

df['cuisines']=df['cuisines'].str.strip()
result=df['cuisines'].value_counts().reset_index()
result.columns=['cuisines','total']
print(result.head(10))
# Out:
#       cuisines  total
# 0  northindian    767
# 1      chinese    623
# 2  continental    421
# 3     fastfood    286
# 4      italian    263
# 5      biryani    255
# 6  southindian    248
# 7         cafe    243
# 8    beverages    213
# 9     desserts    164
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19576\3759866046.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,mydb)

# %%
# North Indian and Chinese cuisines are the most common in Bangalore.
# This indicates high customer demand but also high market saturation.

# %%
#QUS NO 8: Which cuisines receive the highest average ratings?
# Business Value: Identifies high-quality cuisine categories suitable for promotion.

# %%
mycursor.execute("""select cuisines, avg(rate) as avg_rating 
from uber_eats_res_data 
group by cuisines
order by avg_rating""")
out=mycursor.fetchall()
print(tabulate(out,headers=[i[0]for i in mycursor.description],tablefmt='psql'))
# Out:
# +--------------------------------------------------------------------------------------+--------------+
# | cuisines                                                                             |   avg_rating |
# |--------------------------------------------------------------------------------------+--------------|
# | north_indian,_chinese,_south_indian,_street_food                                     |      2.3     |
# | fast_food,_street_food,_north_indian,_biryani                                        |      2.4     |
# | healthy_food,_salad,_fast_food                                                       |      2.4     |
# | north_indian,_chinese,_arabian,_biryani,_fast_food                                   |      2.45    |
# | north_indian,_chinese,_fast_food,_rolls,_juices                                      |      2.5     |
# | andhra,_north_indian,_chinese,_mangalorean                                           |      2.5     |
# | cafe,_american,_pizza                                                                |      2.55    |
# | north_indian,_chinese,_rolls,_biryani,_kebab                                         |      2.6     |
# | north_indian,_chinese,_thai                                                          |      2.6     |
# | italian,_chinese,_japanese                                                           |      2.6     |
# | andhra,_chinese,_biryani                                                             |      2.6     |
# | kerala,_north_indian,_chinese,_rolls,_juices                                         |      2.6     |
# | andhra,_north_indian,_south_indian                                                   |      2.6     |
# | biryani,_north_indian,_italian,_chinese,_sandwich,_desserts                          |      2.61    |
# | pizza,_italian,_salad                                                                |      2.68571 |
# | arabian,_biryani,_north_indian,_chinese,_fast_food                                   |      2.7     |
# | chinese,_fast_food,_cafe,_street_food,_finger_food                                   |      2.7     |
# | biryani,_mughlai,_chinese,_north_indian                                              |      2.7     |
# | mughlai,_chinese,_kebab                                                              |      2.7     |
# | north_indian,_south_indian,_chinese,_beverages                                       |      2.7     |
# | chinese,_north_indian,_continental                                                   |      2.7     |
# | north_indian,_chinese,_south_indian,_beverages                                       |      2.7     |
# | north_indian,_lebanese,_rolls                                                        |      2.7     |
# | south_indian,_chettinad                                                              |      2.7     |
# | hyderabadi,_north_indian,_chinese,_biryani                                           |      2.72857 |
# | andhra,_south_indian,_chinese,_north_indian                                          |      2.78333 |
# | north_indian,_fast_food,_chinese,_burger                                             |      2.8     |
# | north_indian,_mughlai,_chinese,_arabian,_kerala                                      |      2.8     |
# | bengali,_rolls,_chinese                                                              |      2.8     |
# | seafood,_biryani,_hyderabadi,_north_indian                                           |      2.8     |
# | continental,_italian,_pizza                                                          |      2.8     |
# | pizza,_chinese,_north_indian                                                         |      2.8     |
# | north_indian,_chinese,_biryani,_mangalorean                                          |      2.8     |
# | continental,_north_indian,_chinese,_steak                                            |      2.8     |
# | south_indian,_north_indian,_chinese,_kerala                                          |      2.8     |
# | cafe,_tea,_beverages                                                                 |      2.8     |
# | kerala,_chinese,_seafood,_north_indian                                               |      2.8     |
# | north_indian,_south_indian,_chinese,_fast_food,_beverages,_desserts,_street_food     |      2.8     |
# | arabian,_north_indian,_biryani,_chinese,_seafood                                     |      2.81667 |
# | arabian,_north_indian,_seafood,_chinese,_biryani                                     |      2.85    |
# | cafe,_pizza,_fast_food,_beverages                                                    |      2.85385 |
# | north_indian,_south_indian,_chinese,_fast_food                                       |      2.9     |
# | desserts,_italian,_pizza                                                             |      2.9     |
# | north_indian,_chinese,_kerala,_mughlai,_arabian,_beverages                           |      2.9     |
# | north_indian,_chinese,_biryani,_andhra,_mangalorean                                  |      2.9     |
# | north_indian,_south_indian,_seafood,_biryani,_chinese                                |      2.9     |
# | arabian,_north_indian,_chinese,_kerala,_seafood,_biryani                             |      2.9     |
# | south_indian,_street_food,_beverages                                                 |      2.9     |
# | desserts,_cafe,_bakery                                                               |      2.9     |
# | fast_food,_maharashtrian,_rolls                                                      |      2.9     |
# | continental,_north_indian,_desserts,_beverages                                       |      2.9     |
# | fast_food,_desserts,_cafe                                                            |      2.9     |
# | chinese,_fast_food,_cafe                                                             |      2.91111 |
# | south_indian,_street_food,_chinese,_fast_food                                        |      2.95    |
# | rolls,_north_indian,_chinese,_biryani                                                |      2.96    |
# | cafe,_french,_north_indian                                                           |      3       |
# | north_indian,_chinese,_biryani,_kebab                                                |      3       |
# | north_indian,_south_indian,_chinese,_biryani,_seafood                                |      3       |
# | fast_food,_north_indian,_chinese                                                     |      3       |
# | north_indian,_italian,_chinese,_asian                                                |      3       |
# | north_indian,_hyderabadi,_chinese                                                    |      3       |
# | andhra,_biryani,_seafood                                                             |      3       |
# | cafe,_fast_food,_continental                                                         |      3       |
# | asian,_continental,_european,_fast_food,_north_indian,_mughlai,_south_indian         |      3       |
# | cafe,_italian,_tex-mex,_fast_food,_burger                                            |      3       |
# | desserts,_juices,_fast_food                                                          |      3       |
# | kerala,_seafood,_biryani                                                             |      3       |
# | north_eastern,_street_food                                                           |      3       |
# | south_indian,_chinese,_fast_food                                                     |      3       |
# | chinese,_south_indian,_north_indian                                                  |      3       |
# | north_indian,_fast_food,_beverages,_momos                                            |      3.02222 |
# | north_indian,_south_indian,_chinese,_street_food                                     |      3.03333 |
# | biryani,_chinese                                                                     |      3.05    |
# | kerala,_biryani,_south_indian,_north_indian,_chinese,_arabian,_beverages             |      3.05    |
# | north_indian,_chinese,_andhra                                                        |      3.05455 |
# | biryani,_kebab,_continental                                                          |      3.08333 |
# | chinese,_tibetan                                                                     |      3.09167 |
# | north_indian,_chinese,_momos,_rolls                                                  |      3.1     |
# | mughlai,_north_indian,_kebab,_rolls,_chinese                                         |      3.1     |
# | north_indian,_andhra                                                                 |      3.1     |
# | cafe,_italian,_continental,_european                                                 |      3.1     |
# | biryani,_chinese,_fast_food,_north_indian                                            |      3.1     |
# | chinese,_south_indian,_andhra,_north_indian,_biryani                                 |      3.1     |
# | oriya,_north_indian,_chinese                                                         |      3.1     |
# | arabian,_seafood,_north_indian,_chinese,_bbq,_biryani,_beverages                     |      3.1     |
# | pizza,_desserts                                                                      |      3.1     |
# | cafe,_italian,_continental,_european,_biryani,_chinese                               |      3.1     |
# | mangalorean,_chinese,_north_indian,_biryani                                          |      3.1     |
# | north_indian,_chinese,_arabian,_kebab                                                |      3.1     |
# | kerala,_north_indian,_italian,_thai                                                  |      3.1     |
# | north_indian,_momos,_rolls,_fast_food                                                |      3.1     |
# | bakery,_fast_food,_italian                                                           |      3.10385 |
# | bakery,_desserts,_sandwich                                                           |      3.10769 |
# | north_indian,_street_food,_mithai                                                    |      3.11304 |
# | andhra,_biryani,_chinese,_north_indian                                               |      3.11667 |
# | north_indian,_fast_food,_rolls                                                       |      3.125   |
# | south_indian,_north_indian,_chinese,_street_food,_fast_food                          |      3.125   |
# | fast_food,_chinese                                                                   |      3.15    |
# | bengali,_chinese,_north_indian                                                       |      3.15    |
# | street_food,_mithai,_desserts,_north_indian                                          |      3.15    |
# | arabian,_mughlai,_chinese,_kebab,_fast_food                                          |      3.15385 |
# | north_indian,_chinese,_kerala                                                        |      3.17143 |
# | mexican                                                                              |      3.17667 |
# | south_indian,_fast_food,_street_food                                                 |      3.2     |
# | south_indian,_street_food,_fast_food,_desserts,_beverages                            |      3.2     |
# | arabian,_sandwich,_rolls,_burger                                                     |      3.2     |
# | north_indian,_chinese,_continental,_mangalorean                                      |      3.2     |
# | biryani,_fast_food,_rolls                                                            |      3.2     |
# | north_indian,_south_indian,_biryani,_continental                                     |      3.2     |
# | sandwich,_salad,_north_indian,_chinese                                               |      3.2     |
# | north_indian,_fast_food,_biryani                                                     |      3.2     |
# | chinese,_north_eastern                                                               |      3.2     |
# | andhra,_chinese,_north_indian,_south_indian                                          |      3.2     |
# | north_indian,_south_indian,_kerala,_seafood                                          |      3.2     |
# | south_indian,_mangalorean,_kerala                                                    |      3.2     |
# | chettinad,_south_indian,_north_indian                                                |      3.2     |
# | north_indian,_biryani,_chinese,_rolls                                                |      3.2     |
# | fast_food,_biryani,_rolls                                                            |      3.20588 |
# | mughlai,_north_indian,_chinese                                                       |      3.20968 |
# | north_indian,_mughlai,_andhra,_biryani                                               |      3.25    |
# | chettinad,_biryani,_south_indian,_seafood                                            |      3.25    |
# | seafood,_mangalorean,_north_indian,_biryani                                          |      3.25    |
# | south_indian,_north_indian,_fast_food,_street_food                                   |      3.25    |
# | healthy_food,_beverages,_fast_food                                                   |      3.25    |
# | fast_food,_momos,_rolls                                                              |      3.26667 |
# | mughlai,_chinese,_kerala                                                             |      3.26667 |
# | north_indian,_south_indian,_continental                                              |      3.27059 |
# | biryani,_chinese,_north_indian                                                       |      3.27692 |
# | chinese,_tibetan,_north_indian                                                       |      3.27857 |
# | north_indian,_biryani,_andhra,_chinese                                               |      3.29375 |
# | north_indian,_chinese,_rolls                                                         |      3.29459 |
# | bbq,_arabian,_rolls,_chinese,_north_indian,_juices,_kebab,_desserts                  |      3.3     |
# | kerala,_seafood,_south_indian,_biryani                                               |      3.3     |
# | pizza,_chinese,_rolls                                                                |      3.3     |
# | north_indian,_chinese,_fast_food,_beverages                                          |      3.3     |
# | sandwich,_beverages                                                                  |      3.3     |
# | pizza,_italian,_chinese,_rolls,_biryani                                              |      3.3     |
# | bbq,_arabian,_chinese,_kebab,_beverages                                              |      3.3     |
# | kerala,_biryani,_north_indian,_chettinad                                             |      3.3     |
# | chettinad,_south_indian,_chinese,_seafood,_rolls,_north_indian                       |      3.3     |
# | north_indian,_chinese,_rolls,_andhra                                                 |      3.3     |
# | biryani,_hyderabadi,_chinese,_north_indian                                           |      3.3     |
# | andhra,_south_indian,_biryani                                                        |      3.325   |
# | fast_food,_rolls,_momos                                                              |      3.33611 |
# | north_indian,_south_indian,_chinese,_seafood,_kerala,_arabian,_juices                |      3.35    |
# | lebanese                                                                             |      3.37    |
# | oriya,_bengali                                                                       |      3.37273 |
# | juices                                                                               |      3.38    |
# | cafe,_fast_food                                                                      |      3.38226 |
# | north_indian,_mughlai,_biryani,_rolls                                                |      3.38333 |
# | chinese,_north_indian,_seafood                                                       |      3.4     |
# | chettinad,_chinese,_south_indian                                                     |      3.4     |
# | gujarati,_fast_food                                                                  |      3.4     |
# | north_indian,_biryani,_rolls,_beverages                                              |      3.4     |
# | arabian,_kerala,_biryani,_south_indian,_chinese,_bbq                                 |      3.4     |
# | north_indian,_mughlai,_bengali,_chinese                                              |      3.4     |
# | turkish,_chinese                                                                     |      3.4     |
# | continental,_asian,_healthy_food,_burger,_biryani,_pizza,_italian,_fast_food         |      3.4     |
# | andhra,_chinese,_north_indian,_biryani                                               |      3.41111 |
# | north_indian,_kerala,_chinese,_biryani,_seafood,_south_indian                        |      3.41818 |
# | north_indian,_continental,_chinese,_italian                                          |      3.42    |
# | chinese,_north_indian,_biryani,_juices                                               |      3.42    |
# | south_indian,_north_indian,_chinese,_street_food,_juices                             |      3.425   |
# | chinese,_north_indian,_hyderabadi,_biryani                                           |      3.425   |
# | north_indian,_beverages                                                              |      3.42667 |
# | fast_food,_burger,_pizza                                                             |      3.42667 |
# | north_indian,_biryani,_chinese,_mughlai                                              |      3.44    |
# | north_indian,_mughlai,_chinese                                                       |      3.442   |
# | north_indian,_kebab,_biryani,_rolls                                                  |      3.45    |
# | andhra,_south_indian,_hyderabadi                                                     |      3.45    |
# | burger                                                                               |      3.45    |
# | continental,_south_indian,_north_indian,_arabian                                     |      3.45    |
# | north_indian,_chinese,_biryani,_seafood                                              |      3.45294 |
# | chinese,_asian,_american,_seafood                                                    |      3.45455 |
# | arabian,_middle_eastern                                                              |      3.45556 |
# | north_indian,_continental,_chinese                                                   |      3.4625  |
# | healthy_food,_sandwich,_salad                                                        |      3.46364 |
# | biryani,_north_indian,_chinese,_andhra                                               |      3.46667 |
# | south_indian,_north_indian,_fast_food                                                |      3.4697  |
# | chinese,_north_indian                                                                |      3.47671 |
# | fast_food,_burger,_beverages,_cafe,_desserts                                         |      3.48    |
# | biryani,_north_indian                                                                |      3.48144 |
# | north_indian,_mithai                                                                 |      3.48824 |
# | north_indian,_mughlai,_biryani,_chinese                                              |      3.5     |
# | pizza,_sandwich,_burger,_fast_food                                                   |      3.5     |
# | north_indian,_chinese,_fast_food,_bbq                                                |      3.5     |
# | bengali,_north_indian,_oriya                                                         |      3.5     |
# | north_indian,_south_indian,_biryani                                                  |      3.5     |
# | andhra,_north_indian,_chinese,_mangalorean,_seafood,_biryani                         |      3.5     |
# | chinese,_italian,_north_indian                                                       |      3.5     |
# | seafood,_biryani,_south_indian,_north_indian,_chinese,_arabian,_kebab,_kerala        |      3.5     |
# | andhra,_chinese,_north_indian,_hyderabadi                                            |      3.5     |
# | arabian,_lebanese,_chinese,_rolls                                                    |      3.5     |
# | asian,_north_indian,_continental                                                     |      3.5     |
# | north_indian,_bengali                                                                |      3.5     |
# | north_indian,_biryani,_mughlai,_kebab                                                |      3.5     |
# | lucknowi,_chinese                                                                    |      3.5     |
# | kashmiri                                                                             |      3.5     |
# | north_indian,_chinese,_thai,_continental                                             |      3.5     |
# | north_indian,_lucknowi,_mughlai,_biryani                                             |      3.5     |
# | south_indian,_chettinad,_chinese                                                     |      3.5     |
# | biryani,_north_indian,_mughlai,_fast_food                                            |      3.5     |
# | north_indian,_continental,_chinese,_seafood                                          |      3.5     |
# | north_indian,_chinese,_mughlai,_rolls                                                |      3.5     |
# | north_indian,_chinese,_kebab,_beverages                                              |      3.5     |
# | north_indian,_chinese,_seafood,_mangalorean                                          |      3.5     |
# | south_indian,_kerala,_north_indian,_chinese                                          |      3.5     |
# | bengali,_north_indian,_chinese                                                       |      3.51379 |
# | mithai,_north_indian,_street_food,_chinese                                           |      3.51429 |
# | south_indian,_biryani,_chinese,_north_indian                                         |      3.51579 |
# | north_indian,_biryani,_chinese                                                       |      3.51778 |
# | north_indian,_chinese,_fast_food                                                     |      3.51974 |
# | north_indian,_chinese,_european                                                      |      3.52    |
# | north_indian,_chinese,_street_food,_biryani                                          |      3.52    |
# | kerala,_chinese                                                                      |      3.52105 |
# | andhra,_biryani,_south_indian                                                        |      3.525   |
# | healthy_food,_sandwich                                                               |      3.52857 |
# | andhra,_south_indian,_north_indian                                                   |      3.53077 |
# | bakery,_cafe                                                                         |      3.53158 |
# | biryani,_kerala,_mughlai,_street_food,_north_indian,_chinese,_south_indian,_andhra   |      3.54    |
# | pizza,_fast_food                                                                     |      3.54151 |
# | tibetan,_momos                                                                       |      3.54167 |
# | arabian,_fast_food                                                                   |      3.54444 |
# | mughlai,_kebab,_chinese                                                              |      3.54444 |
# | north_indian,_chinese                                                                |      3.54781 |
# | arabian,_chinese,_kerala,_north_indian,_biryani                                      |      3.55    |
# | chinese,_north_indian,_fast_food                                                     |      3.55    |
# | cafe,_fast_food,_chinese                                                             |      3.55385 |
# | south_indian,_chettinad,_chinese,_north_indian,_andhra,_seafood                      |      3.55714 |
# | north_indian,_chinese,_biryani,_rolls                                                |      3.5625  |
# | south_indian,_fast_food,_chinese,_north_indian,_street_food                          |      3.56364 |
# | north_indian,_kebab,_fast_food                                                       |      3.56667 |
# | mughlai,_north_indian,_biryani                                                       |      3.56667 |
# | chinese,_seafood,_biryani                                                            |      3.56667 |
# | south_indian,_street_food                                                            |      3.56667 |
# | north_indian,_seafood,_biryani,_kerala                                               |      3.56667 |
# | pizza,_italian                                                                       |      3.56721 |
# | italian,_pizza                                                                       |      3.56912 |
# | ice_cream,_bakery,_desserts                                                          |      3.57059 |
# | chettinad,_south_indian                                                              |      3.57647 |
# | salad,_fast_food                                                                     |      3.57813 |
# | oriya                                                                                |      3.58    |
# | north_indian,_chinese,_kebab                                                         |      3.58125 |
# | bohri                                                                                |      3.58333 |
# | bengali                                                                              |      3.58387 |
# | italian,_fast_food,_cafe,_european                                                   |      3.6     |
# | goan,_seafood,_north_indian,_chinese,_biryani                                        |      3.6     |
# | south_indian,_north_indian,_chinese,_street_food,_beverages                          |      3.6     |
# | biryani,_north_indian,_rolls                                                         |      3.6     |
# | cafe,_continental,_pizza,_burger,_beverages                                          |      3.6     |
# | cafe,_italian,_pizza,_chinese                                                        |      3.6     |
# | italian,_pizza,_burger                                                               |      3.6     |
# | north_indian,_chinese,_south_indian,_kerala                                          |      3.6     |
# | italian,_mexican,_mediterranean,_north_indian,_continental                           |      3.6     |
# | continental,_chinese,_fast_food,_rolls,_momos                                        |      3.6     |
# | bengali,_seafood,_oriya,_north_indian,_biryani                                       |      3.6     |
# | north_indian,_chinese,_andhra,_biryani                                               |      3.6     |
# | north_indian,_healthy_food                                                           |      3.6     |
# | biryani,_chinese,_north_indian,_kebab                                                |      3.6     |
# | biryani,_fast_food,_rolls,_momos                                                     |      3.6     |
# | biryani,_mughlai,_north_indian                                                       |      3.6     |
# | north_indian,_chinese,_arabian,_mughlai                                              |      3.6     |
# | north_indian,_asian,_continental,_bengali,_momos                                     |      3.6     |
# | north_indian,_south_indian,_chinese,_italian                                         |      3.6     |
# | biryani,_south_indian,_north_indian,_chinese                                         |      3.6     |
# | biryani,_chinese,_continental,_north_indian,_pizza                                   |      3.6     |
# | biryani,_south_indian,_north_indian                                                  |      3.6     |
# | north_indian,_biryani,_mughlai,_rolls                                                |      3.6     |
# | arabian,_mediterranean,_north_indian                                                 |      3.6     |
# | north_indian,_chinese,_seafood,_rolls                                                |      3.6     |
# | biryani,_chettinad,_chinese                                                          |      3.6     |
# | fast_food,_continental,_burger                                                       |      3.6     |
# | street_food,_chinese,_italian,_north_indian                                          |      3.6     |
# | bakery,_fast_food,_pizza,_burger                                                     |      3.6     |
# | chinese,_north_indian,_mughlai                                                       |      3.6     |
# | salad,_biryani,_chinese,_north_indian,_kerala,_desserts,_seafood,_south_indian       |      3.6     |
# | seafood,_biryani,_south_indian,_chettinad,_chinese,_arabian,_andhra,_kerala          |      3.6     |
# | pizza,_fast_food,_bbq                                                                |      3.61    |
# | kerala,_north_indian,_chinese                                                        |      3.61071 |
# | north_indian,_chinese,_biryani,_andhra                                               |      3.61111 |
# | south_indian,_chinese,_north_indian                                                  |      3.6129  |
# | street_food,_rolls                                                                   |      3.61429 |
# | healthy_food,_chinese,_biryani,_north_indian,_continental,_salad,_american,_burger   |      3.625   |
# | north_indian,_fast_food,_beverages                                                   |      3.62857 |
# | biryani,_mughlai,_chinese                                                            |      3.63077 |
# | fast_food,_burger                                                                    |      3.63243 |
# | south_indian,_north_indian,_chinese,_street_food                                     |      3.63301 |
# | continental,_italian,_chinese,_north_indian                                          |      3.63333 |
# | cafe,_burger,_italian,_fast_food                                                     |      3.63333 |
# | biryani,_north_indian,_chinese                                                       |      3.63723 |
# | continental,_american,_south_indian,_italian,_north_indian,_chinese                  |      3.64    |
# | south_indian,_north_indian,_chinese                                                  |      3.64077 |
# | cafe,_beverages,_continental,_north_indian,_chinese                                  |      3.64444 |
# | north_indian,_chinese,_biryani,_south_indian                                         |      3.65    |
# | continental,_south_indian,_finger_food,_pizza,_seafood                               |      3.65    |
# | south_indian,_north_indian,_street_food,_chinese,_beverages                          |      3.65    |
# | south_indian,_chinese,_north_indian,_street_food                                     |      3.65    |
# | andhra,_north_indian,_chinese,_biryani                                               |      3.65455 |
# | kerala,_chinese,_north_indian                                                        |      3.65714 |
# | fast_food,_street_food                                                               |      3.66154 |
# | andhra,_south_indian,_north_indian,_biryani                                          |      3.66154 |
# | mithai,_north_indian,_street_food                                                    |      3.6625  |
# | andhra,_north_indian,_chinese,_seafood,_biryani                                      |      3.66667 |
# | north_indian,_bengali,_chinese                                                       |      3.66667 |
# | north_indian,_chinese,_street_food                                                   |      3.67222 |
# | fast_food,_street_food,_juices                                                       |      3.675   |
# | andhra,_chinese,_north_indian                                                        |      3.67727 |
# | north_indian,_chinese,_beverages                                                     |      3.67778 |
# | north_indian,_south_indian,_chinese                                                  |      3.68182 |
# | chinese,_continental,_burger,_pizza                                                  |      3.68333 |
# | north_indian,_chinese,_mughlai                                                       |      3.68605 |
# | fast_food,_north_indian                                                              |      3.68846 |
# | south_indian,_chettinad,_kerala,_seafood                                             |      3.69091 |
# | kerala,_biryani,_south_indian,_north_indian,_chinese,_seafood,_juices                |      3.69333 |
# | chinese,_thai,_continental,_north_indian                                             |      3.7     |
# | fast_food,_desserts,_beverages                                                       |      3.7     |
# | chinese,_north_indian,_pizza,_italian                                                |      3.7     |
# | cafe,_italian,_beverages                                                             |      3.7     |
# | fast_food,_north_indian,_south_indian                                                |      3.7     |
# | chinese,_north_indian,_salad,_fast_food                                              |      3.7     |
# | biryani,_italian,_bbq                                                                |      3.7     |
# | fast_food,_italian                                                                   |      3.7     |
# | biryani,_fast_food,_north_indian,_chinese                                            |      3.7     |
# | chinese,_fast_food,_continental                                                      |      3.7     |
# | fast_food,_tea,_beverages                                                            |      3.7     |
# | fast_food,_burger,_italian,_beverages                                                |      3.7     |
# | cafe,_continental,_chinese,_momos                                                    |      3.7     |
# | bakery,_fast_food,_desserts                                                          |      3.7     |
# | seafood,_north_indian,_chinese,_continental,_mangalorean                             |      3.7     |
# | finger_food,_chinese,_north_indian                                                   |      3.7     |
# | north_indian,_chinese,_biryani,_beverages                                            |      3.7     |
# | north_indian,_chinese,_south_indian,_fast_food,_juices                               |      3.7     |
# | biryani,_south_indian,_north_indian,_chinese,_andhra                                 |      3.7     |
# | cafe,_sandwich,_north_indian,_beverages,_desserts                                    |      3.7     |
# | mangalorean                                                                          |      3.7     |
# | south_indian,_street_food,_juices                                                    |      3.7     |
# | ice_cream,_desserts,_juices                                                          |      3.7     |
# | north_indian,_chinese,_continental,_pizza                                            |      3.7     |
# | bakery,_fast_food,_pizza,_burger,_cafe                                               |      3.7     |
# | north_indian,_south_indian,_italian,_chinese,_fast_food                              |      3.7     |
# | street_food,_burger,_fast_food                                                       |      3.7     |
# | kerala,_seafood,_south_indian,_chinese,_north_indian,_charcoal_chicken,_beverages    |      3.7     |
# | biryani,_mughlai,_chinese,_arabian                                                   |      3.7     |
# | fast_food,_chinese,_rolls                                                            |      3.7     |
# | chinese,_seafood,_momos                                                              |      3.7     |
# | fast_food,_sandwich,_south_indian                                                    |      3.7     |
# | continental,_steak,_chinese,_salad,_desserts,_seafood,_italian                       |      3.7     |
# | mughlai,_fast_food                                                                   |      3.7     |
# | fast_food,_sandwich,_italian                                                         |      3.7     |
# | chinese,_continental,_north_indian,_pizza,_south_indian                              |      3.7     |
# | cafe,_bakery,_desserts                                                               |      3.7     |
# | chinese,_north_indian,_arabian,_biryani                                              |      3.7     |
# | chinese,_fast_food,_italian                                                          |      3.7     |
# | north_indian,_chinese,_middle_eastern                                                |      3.7     |
# | fast_food,_sandwich,_beverages                                                       |      3.7     |
# | chinese,_north_indian,_arabian                                                       |      3.7     |
# | finger_food,_fast_food                                                               |      3.7     |
# | desserts,_street_food,_mithai                                                        |      3.7     |
# | continental,_healthy_food                                                            |      3.7     |
# | biryani,_north_indian,_mangalorean,_seafood                                          |      3.7     |
# | street_food,_north_indian,_rolls                                                     |      3.7     |
# | north_indian,_andhra,_chinese                                                        |      3.7     |
# | american,_fast_food                                                                  |      3.7     |
# | north_indian,_seafood,_middle_eastern,_chinese                                       |      3.7     |
# | north_indian,_gujarati,_street_food                                                  |      3.7     |
# | arabian,_chinese,_fast_food,_beverages                                               |      3.7     |
# | chinese,_north_indian,_mexican,_fast_food                                            |      3.7     |
# | rajasthani,_north_indian,_chinese                                                    |      3.7     |
# | south_indian,_andhra,_biryani                                                        |      3.7     |
# | chinese,_biryani,_pizza,_italian,_north_indian                                       |      3.7     |
# | north_indian,_chinese,_south_indian,_juices                                          |      3.7     |
# | north_indian,_mughlai,_biryani,_chinese,_kebab                                       |      3.7     |
# | chinese,_thai,_seafood,_malaysian                                                    |      3.7     |
# | cafe,_north_indian,_chinese,_continental                                             |      3.7     |
# | continental,_biryani,_pizza,_north_indian,_chinese,_momos,_andhra,_kebab             |      3.7     |
# | north_indian,_chinese,_oriya,_mithai                                                 |      3.7     |
# | south_indian,_north_indian,_fast_food,_chinese                                       |      3.7     |
# | bengali,_north_indian,_chinese,_biryani                                              |      3.7     |
# | biryani,_chinese,_fast_food                                                          |      3.7     |
# | north_indian,_chinese,_street_food,_sandwich                                         |      3.7     |
# | andhra,_hyderabadi,_biryani                                                          |      3.7     |
# | bihari                                                                               |      3.7     |
# | cafe,_mediterranean,_italian,_pizza,_continental                                     |      3.7     |
# | biryani,_south_indian,_fast_food                                                     |      3.7     |
# | cafe,_fast_food,_north_indian                                                        |      3.7     |
# | north_indian,_south_indian,_asian,_italian,_continental                              |      3.7     |
# | mughlai,_north_indian,_biryani,_chinese                                              |      3.7     |
# | cafe,_tea                                                                            |      3.7     |
# | continental,_italian,_cafe,_beverages,_desserts                                      |      3.7     |
# | andhra,_continental,_chinese                                                         |      3.7     |
# | chinese,_north_indian,_cafe                                                          |      3.7     |
# | north_indian,_street_food                                                            |      3.7043  |
# | andhra                                                                               |      3.7087  |
# | biryani                                                                              |      3.71243 |
# | north_indian,_chinese,_bbq                                                           |      3.71429 |
# | north_indian,_chinese,_biryani                                                       |      3.71522 |
# | healthy_food                                                                         |      3.71579 |
# | north_indian,_kebab,_chinese,_fast_food                                              |      3.71667 |
# | chinese,_thai,_momos,_vietnamese                                                     |      3.71707 |
# | biryani,_north_indian,_charcoal_chicken,_chinese,_seafood,_rolls                     |      3.71818 |
# | north_indian,_chinese,_south_indian,_fast_food                                       |      3.72308 |
# | north_indian,_fast_food                                                              |      3.72449 |
# | kashmiri,_cafe                                                                       |      3.725   |
# | kerala,_south_indian,_north_indian,_chinese                                          |      3.72727 |
# | kerala,_seafood                                                                      |      3.73111 |
# | chinese,_thai,_seafood                                                               |      3.73333 |
# | biryani,_rolls                                                                       |      3.73333 |
# | mangalorean,_seafood,_north_indian                                                   |      3.73333 |
# | south_indian,_biryani                                                                |      3.73333 |
# | continental,_burger,_cafe,_steak                                                     |      3.73333 |
# | cafe,_bakery,_continental                                                            |      3.74    |
# | kerala,_konkan                                                                       |      3.74    |
# | north_indian,_fast_food,_street_food                                                 |      3.7431  |
# | andhra,_biryani,_south_indian,_chinese                                               |      3.74444 |
# | mithai,_fast_food                                                                    |      3.74545 |
# | chinese,_thai                                                                        |      3.74615 |
# | burger,_fast_food                                                                    |      3.74697 |
# | andhra,_north_indian                                                                 |      3.748   |
# | north_indian,_south_indian,_chinese,_continental                                     |      3.74878 |
# | chinese,_north_indian,_thai                                                          |      3.75    |
# | fast_food,_north_indian,_chinese,_mughlai,_rolls                                     |      3.75    |
# | roast_chicken,_burger                                                                |      3.75    |
# | north_indian,_afghani                                                                |      3.75    |
# | cafe,_north_indian,_chinese                                                          |      3.75    |
# | andhra,_north_indian,_biryani,_beverages                                             |      3.75    |
# | pizza                                                                                |      3.75542 |
# | biryani,_kebab                                                                       |      3.76232 |
# | north_indian                                                                         |      3.76337 |
# | kerala,_seafood,_south_indian,_north_indian,_chinese                                 |      3.76364 |
# | arabian,_kerala,_north_indian,_chinese,_bbq                                          |      3.76667 |
# | burger,_cafe,_desserts,_sandwich,_italian                                            |      3.76667 |
# | north_indian,_chinese,_juices                                                        |      3.76667 |
# | ice_cream,_fast_food,_burger,_pizza,_sandwich,_desserts,_beverages                   |      3.76667 |
# | north_indian,_south_indian,_asian                                                    |      3.76667 |
# | cafe,_continental,_thai,_chinese                                                     |      3.76667 |
# | continental,_italian,_north_indian,_chinese                                          |      3.76667 |
# | south_indian,_north_indian                                                           |      3.77222 |
# | andhra,_seafood,_north_indian,_chinese                                               |      3.77273 |
# | street_food,_mithai                                                                  |      3.77368 |
# | arabian,_north_indian                                                                |      3.775   |
# | north_indian,_chinese,_biryani,_kebab,_juices                                        |      3.775   |
# | south_indian,_continental,_north_indian                                              |      3.775   |
# | fast_food                                                                            |      3.77667 |
# | biryani,_andhra                                                                      |      3.77692 |
# | north_indian,_chinese,_continental                                                   |      3.77885 |
# | north_indian,_south_indian,_biryani,_beverages                                       |      3.78333 |
# | biryani,_andhra,_north_indian                                                        |      3.78333 |
# | north_indian,_chinese,_cafe,_desserts                                                |      3.7875  |
# | kerala                                                                               |      3.78889 |
# | north_indian,_kerala                                                                 |      3.79    |
# | american,_sandwich                                                                   |      3.79167 |
# | north_indian,_afghan                                                                 |      3.79167 |
# | north_indian,_mughlai,_rolls,_fast_food                                              |      3.79167 |
# | cafe,_continental,_fast_food                                                         |      3.79231 |
# | north_indian,_chinese,_mangalorean                                                   |      3.79375 |
# | cafe,_beverages,_fast_food                                                           |      3.79655 |
# | italian,_european                                                                    |      3.8     |
# | cafe,_continental,_salad                                                             |      3.8     |
# ...
# | modern_indian                                                                        |      4.38594 |
# | continental,_north_indian,_pizza,_italian                                            |      4.4     |
# | north_indian,_chinese,_continental,_mexican                                          |      4.4     |
# | finger_food,_continental,_seafood                                                    |      4.4     |
# | north_indian,_japanese                                                               |      4.4     |
# | north_indian,_chinese,_continental,_momos                                            |      4.4     |
# | american,_cafe,_continental                                                          |      4.4     |
# | asian,_thai,_chinese,_bbq,_momos                                                     |      4.4     |
# | burger,_continental,_italian,_beverages                                              |      4.4     |
# | seafood,_konkan,_mangalorean                                                         |      4.4     |
# | healthy_food,_mediterranean,_desserts,_italian,_pizza,_salad,_kebab                  |      4.4     |
# | asian,_north_indian,_thai                                                            |      4.4     |
# | asian,_japanese,_thai                                                                |      4.4     |
# | asian,_burger,_chinese,_finger_food                                                  |      4.4     |
# | north_indian,_chinese,_continental,_italian                                          |      4.4     |
# | modern_indian,_european,_asian                                                       |      4.4     |
# | cafe,_european,_continental                                                          |      4.4     |
# | cafe,_continental,_healthy_food,_sandwich,_pizza,_desserts,_beverages                |      4.4     |
# | cafe,_north_indian,_pizza,_sandwich,_salad                                           |      4.4     |
# | north_indian,_biryani,_awadhi,_mughlai                                               |      4.4     |
# | malaysian,_thai,_singaporean,_asian,_chinese,_momos                                  |      4.4     |
# | south_indian,_kerala,_seafood                                                        |      4.4     |
# | chinese,_thai,_asian,_malaysian,_vietnamese,_sri_lankan,_burmese                     |      4.4     |
# | mediterranean,_pizza,_italian,_beverages                                             |      4.4     |
# | chinese,_continental,_north_indian,_burger,_pizza,_seafood                           |      4.4     |
# | american,_continental,_steak                                                         |      4.4     |
# | cafe,_american,_asian,_north_indian                                                  |      4.4     |
# | continental,_fast_food,_european                                                     |      4.4     |
# | asian,_burger,_pizza,_chinese,_finger_food                                           |      4.4     |
# | mithai                                                                               |      4.4     |
# | asian,_continental,_european,_north_indian                                           |      4.4     |
# | mediterranean,_continental,_french,_italian                                          |      4.4     |
# | north_indian,_chinese,_fast_food,_beverages,_desserts                                |      4.4     |
# | biryani,_north_indian,_chinese,_mughlai                                              |      4.4     |
# | continental,_mexican,_burger,_desserts,_italian,_pizza,_north_indian,_chinese        |      4.4     |
# | middle_eastern,_fast_food,_rolls                                                     |      4.4     |
# | cafe,_burger,_pizza,_sandwich                                                        |      4.4     |
# | asian,_chinese,_thai,_korean                                                         |      4.4     |
# | healthy_food,_desserts                                                               |      4.4     |
# | french,_sandwich,_salad                                                              |      4.4     |
# | vietnamese,_salad                                                                    |      4.4     |
# | seafood,_continental,_north_indian,_south_indian                                     |      4.4     |
# | continental,_north_indian,_chinese,_pizza,_thai                                      |      4.4     |
# | american,_south_indian,_thai,_pizza,_italian                                         |      4.4     |
# | asian,_chinese,_japanese,_bbq                                                        |      4.4     |
# | cafe,_salad,_healthy_food,_mexican                                                   |      4.4     |
# | ice_cream,_pizza,_beverages                                                          |      4.4     |
# | kebab,_rolls                                                                         |      4.4     |
# | north_indian,_mughlai,_desserts                                                      |      4.4     |
# | continental,_mediterranean,_south_indian,_north_indian,_asian                        |      4.4     |
# | asian,_japanese,_vietnamese,_korean,_chinese,_thai                                   |      4.4     |
# | cafe,_italian,_fast_food                                                             |      4.4     |
# | parsi,_north_indian                                                                  |      4.40667 |
# | finger_food,_continental,_north_indian                                               |      4.40769 |
# | italian,_salad                                                                       |      4.40769 |
# | pizza,_cafe,_italian                                                                 |      4.41059 |
# | north_indian,_mediterranean,_european,_bbq                                           |      4.41875 |
# | korean,_chinese,_japanese                                                            |      4.42    |
# | ice_cream,_cafe,_pizza,_burger,_desserts,_beverages                                  |      4.42424 |
# | north_indian,_continental,_chinese,_thai                                             |      4.425   |
# | cafe,_salad                                                                          |      4.42667 |
# | continental,_italian,_north_indian,_mexican                                          |      4.44    |
# | american,_north_indian,_pizza,_finger_food,_continental,_italian                     |      4.44615 |
# | modern_indian,_european,_american                                                    |      4.45    |
# | american,_continental,_pizza                                                         |      4.45    |
# | asian,_thai                                                                          |      4.45455 |
# | cafe,_tea,_beverages,_fast_food                                                      |      4.45714 |
# | continental,_mediterranean,_north_indian,_chinese,_finger_food                       |      4.475   |
# | chinese,_continental,_north_indian,_mexican                                          |      4.48    |
# | north_indian,_mughlai,_biryani,_south_indian,_beverages                              |      4.48    |
# | north_indian,_continental,_cafe                                                      |      4.48333 |
# | european,_continental                                                                |      4.48696 |
# | cafe,_desserts,_continental                                                          |      4.4875  |
# | north_indian,_asian,_seafood,_chinese                                                |      4.5     |
# | continental,_mexican,_chinese,_north_indian                                          |      4.5     |
# | north_indian,_mughlai,_italian                                                       |      4.5     |
# | italian,_pizza,_salad                                                                |      4.5     |
# | american,_continental,_salad                                                         |      4.5     |
# | american,_bbq                                                                        |      4.5     |
# | mangalorean,_konkan,_seafood,_kerala                                                 |      4.5     |
# | malaysian,_singaporean,_thai                                                         |      4.5     |
# | american,_cafe,_continental,_french,_burger,_mexican,_desserts,_pizza                |      4.5     |
# | chinese,_beverages,_momos,_thai                                                      |      4.5     |
# | continental,_north_indian,_asian,_italian                                            |      4.5     |
# | north_indian,_chinese,_continental,_thai,_salad                                      |      4.5     |
# | north_indian,_mughlai,_salad                                                         |      4.5     |
# | cafe,_continental,_mediterranean,_beverages                                          |      4.5     |
# | lebanese,_turkish                                                                    |      4.5     |
# | steak,_continental,_burger,_bbq                                                      |      4.5     |
# | chinese,_sushi,_asian,_thai                                                          |      4.5     |
# | desserts,_beverages,_cafe,_ice_cream                                                 |      4.5     |
# | continental,_north_indian,_chinese,_american,_pizza,_finger_food                     |      4.5     |
# | continental,_american,_italian,_modern_indian,_pizza,_burger                         |      4.5     |
# | ice_cream,_cafe,_beverages,_burger,_desserts,_pizza                                  |      4.5     |
# | asian,_european,_italian,_korean,_malaysian,_thai,_vietnamese,_chinese               |      4.5     |
# | american,_continental,_north_indian,_salad                                           |      4.5     |
# | american,_continental                                                                |      4.5     |
# | vietnamese,_thai,_burmese,_japanese                                                  |      4.5     |
# | pizza,_north_indian,_modern_indian                                                   |      4.5     |
# | north_indian,_chinese,_mughlai,_desserts                                             |      4.5     |
# | momos,_chinese,_fast_food                                                            |      4.5     |
# | north_indian,_mughlai,_lucknowi                                                      |      4.5     |
# | continental,_mediterranean,_italian,_north_indian,_finger_food,_asian,_momos         |      4.5     |
# | mediterranean,_european,_salad                                                       |      4.52    |
# | mediterranean,_pizza,_continental,_seafood,_salad                                    |      4.52308 |
# | north_indian,_european,_mediterranean,_bbq,_kebab                                    |      4.52821 |
# | north_indian,_south_indian,_chinese,_continental,_mangalorean                        |      4.53333 |
# | continental,_asian,_italian,_north_indian                                            |      4.53636 |
# | asian,_japanese,_korean,_indonesian,_malaysian,_singaporean                          |      4.53684 |
# | american,_tex-mex,_burger,_bbq                                                       |      4.55    |
# | cafe,_pizza,_beverages                                                               |      4.55833 |
# | continental,_finger_food,_asian,_north_indian                                        |      4.56    |
# | continental,_north_indian,_chinese,_american                                         |      4.56667 |
# | african,_burger                                                                      |      4.59091 |
# | cafe,_american,_burger,_steak                                                        |      4.59535 |
# | american,_north_indian,_chinese,_finger_food                                         |      4.6     |
# | european,_italian,_desserts,_salad,_juices,_steak                                    |      4.6     |
# | spanish,_italian,_mediterranean,_european,_salad                                     |      4.6     |
# | american,_north_indian,_salad                                                        |      4.6     |
# | desserts,_continental                                                                |      4.6     |
# | cafe,_american,_burger,_beverages                                                    |      4.6     |
# | continental,_finger_food,_asian,_chinese                                             |      4.6     |
# | asian,_thai,_vietnamese,_malaysian,_beverages                                        |      4.6     |
# | north_indian,_chinese,_mughlai,_mexican,_bbq                                         |      4.6     |
# | biryani,_mughlai,_andhra                                                             |      4.6     |
# | mangalorean,_seafood,_south_indian,_north_indian,_chinese,_mughlai                   |      4.6     |
# | african,_burger,_desserts,_beverages,_fast_food                                      |      4.6     |
# | goan,_asian,_north_indian,_european,_continental                                     |      4.6     |
# | chinese,_asian,_cantonese,_tea                                                       |      4.6     |
# | cafe,_american,_burger                                                               |      4.6     |
# | bbq                                                                                  |      4.6     |
# | continental,_north_indian,_bbq,_steak                                                |      4.62    |
# | continental,_bbq,_salad                                                              |      4.64444 |
# | chinese,_continental,_north_indian,_finger_food                                      |      4.65    |
# | american,_continental,_north_indian,_mediterranean                                   |      4.65    |
# | north_indian,_thai,_japanese,_continental,_cafe                                      |      4.68824 |
# | sushi,_japanese,_chinese,_thai                                                       |      4.7     |
# | continental,_european,_bbq,_chinese,_asian                                           |      4.7     |
# | chinese,_american,_continental,_italian,_north_indian                                |      4.7     |
# | bbq,_north_indian,_continental,_chinese                                              |      4.7     |
# | asian,_burmese                                                                       |      4.7     |
# | italian,_american,_pizza                                                             |      4.7     |
# | north_indian,_european,_mediterranean                                                |      4.7     |
# | continental,_asian,_north_indian                                                     |      4.72381 |
# | continental,_north_indian,_chinese,_european,_bbq,_finger_food,_asian                |      4.73077 |
# | american,_tex-mex,_burger,_bbq,_mexican                                              |      4.75    |
# | european,_mediterranean,_north_indian,_bbq                                           |      4.78947 |
# | north_indian,_european,_mediterranean,_bbq                                           |      4.8     |
# | asian,_mediterranean,_north_indian,_bbq                                              |      4.8     |
# | continental,_north_indian,_italian,_south_indian,_finger_food                        |      4.9     |
# | healthy_food,_salad,_mediterranean                                                   |      4.9     |
# | asian,_chinese,_thai,_momos                                                          |      4.9     |
# +--------------------------------------------------------------------------------------+--------------+

# %%
query=("select cuisines,rate from uber_eats_res_data")

df=pd.read_sql(query,mydb)
df=df.dropna(subset=['cuisines','rate'])

df['cuisines']=df['cuisines'].str.split(',')

df=df.explode('cuisines')

df['cuisines']=df['cuisines'].str.strip()
df['cuisines']=df['cuisines'].str.replace('_','')
df['cuisines']=df['cuisines'].str.lower()

result=df.groupby('cuisines')['rate'].mean().reset_index()

result=result.sort_values(by='rate',ascending=False)
print(result.head(10))
# Out:
#         cuisines      rate
# 23     cantonese  4.600000
# 2        african  4.523529
# 82   singaporean  4.414894
# 12       belgian  4.366667
# 56     malaysian  4.366667
# 62  modernindian  4.323448
# 86     srilankan  4.306667
# 46        jewish  4.300000
# 95         vegan  4.300000
# 8         awadhi  4.280000
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19576\4082093678.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,mydb)

# %%
counts=df['cuisines'].value_counts()
valid=counts[counts>50].index
filtered_df=df[df['cuisines'].isin(valid)]

result=filtered_df.groupby('cuisines')['rate'].mean().reset_index()
result=result.sort_values(by='rate',ascending=False)
print(result.head(10))
# Out:
#          cuisines      rate
# 35      malaysian  4.366667
# 41   modernindian  4.323448
# 37  mediterranean  4.274603
# 27       japanese  4.268263
# 16       european  4.259871
# 32         korean  4.237008
# 3           asian  4.236138
# 25     indonesian  4.217722
# 58        turkish  4.194915
# 5             bbq  4.177321

# %%
# After filtering cuisines with sufficient data, 
# I found that Malaysian, Modern Indian, and Mediterranean cuisines have the highest average ratings.
# This indicates that these cuisines deliver better customer satisfaction and belong to the premium segment.
#These categories can be targeted for promotions or high-end restaurant investments.

# %%
#QUS NO 9: # Which cuisines perform well despite having fewer restaurants?
# Business Value: Highlights niche opportunities for differentiation.

# %%
query = ("select cuisines,rate from uber_eats_res_data")
df=pd.read_sql(query,mydb)

df=df.dropna(subset=['cuisines','rate'])

df['cuisines']=df['cuisines'].str.split(',')

df=df.explode('cuisines')

df['cuisines']=df['cuisines'].str.strip()
df['cuisines']=df['cuisines'].str.replace('_','')
df['cuisines']=df['cuisines'].str.lower()

res1=df.groupby('cuisines').agg(total_restaurents=('cuisines','count'),
avg_rating=('rate','mean')).reset_index()

niche=res1[(res1['total_restaurents']<20)&(res1['avg_rating']>4.2)]

niche=niche.sort_values(by='avg_rating',ascending=False)
print(niche)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19576\657193756.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,mydb)
#       cuisines  total_restaurents  avg_rating
# 23   cantonese                  6    4.600000
# 2      african                 17    4.523529
# 12     belgian                  3    4.366667
# 86   srilankan                 15    4.306667
# 46      jewish                  6    4.300000
# 95       vegan                  6    4.300000
# 8       awadhi                 15    4.280000
# 34      german                  3    4.266667
# 18     british                  7    4.242857
# 73  portuguese                 11    4.227273

# %%
# These cuisines represent niche opportunities where demand quality is high but supply is limited. 
# Expanding these categories can help platforms differentiate and attract premium customers.”
# Cuisines like Cantonese, African, and Belgian perform exceptionally well despite low availability, 
# indicating strong niche demand and expansion opportunities.

# %%
#QUS NO 10: What is the relationship between restaurant cost and rating?
# Business Value: Determines whether higher pricing translates to better customer perception.

# %%
mycursor.execute(""" select 
case
when `approx_cost(for two people)` <= 500 then 'low'
when `approx_cost(for two people)` between 501 and 1500 then 'mid'
else 'premium' 
end as price_category,
count(*) as total_restaurents,
avg(rate) as avg_rating
from uber_eats_res_data 
group by price_category
order by avg_rating desc; 
""")
out=mycursor.fetchall()
print(tabulate(out,headers=[i[0]for i in mycursor.description],tablefmt='psql'))
# Out:
# +------------------+---------------------+--------------+
# | price_category   |   total_restaurents |   avg_rating |
# |------------------+---------------------+--------------|
# | premium          |                1554 |      4.22696 |
# | mid              |               11824 |      3.95707 |
# | low              |                9774 |      3.78977 |
# +------------------+---------------------+--------------+

# %%
# There is a mild positive relationship between cost and rating, 
# but high pricing does not guarantee significantly better customer satisfaction.
